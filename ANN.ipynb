# %% [markdown]
# ---
# ---
#
# # 0. Imports
#
# ---
# ---

# %%
import numpy as np
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_digits

# import tqdm for progress bar
from tqdm.auto import tqdm

# import PyTorch related libraries
import torch
from torch import nn

import torchvision 
from torchvision import datasets
from torchvision import transforms
from torchvision.transforms import ToTensor

from torch.utils.data import DataLoader

# import helper functions tools
from helper_functions import load_cifar10
from helper_functions import decision_surface
from helper_functions import decision_surface_torch

# general settings
plt.style.use('ggplot')
# device = 'cuda' if torch.cuda.is_available() else 'cpu'
np.set_printoptions(precision=2)
# Out:
# C:\Users\alireza\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\alireza\anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
# C:\Users\alireza\anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.23-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# ---
# ---
#
#
# # 1. Definitions
#
#
# ---
# ---
#
# The first section of the notebook contains the definitions of all tools used in the section two of the notebook.

# %% [markdown]
# ## 1.1 implementing neural network architecture from scratch
#
# from now on, we are going to call all instances of `Dense_Layer` class as **independent models**.

# %% [markdown]
# ### 1.1.1 Base Layer

# %%
# The parent class of all Layers
class Layer:
    def __init__(self):
        self.input = 0
        self.output = 0
    def forward(self):
        pass
    def backward(self):
        pass

# %% [markdown]
# ### 1.1.2 Dense Layer

# %%
# Provides the ability to create a sequential network of arbitrary number of dense layers (fully connected).
class Dense_Layer(Layer):
    def __init__(self, input_size, output_size):
        np.random.seed(10)
        self.weights = np.random.randn(output_size, input_size) * 0.01
        self.bias = np.random.randn(output_size, 1) * 0.01
    
    def forward(self, Xs):
        self.input = Xs
        self.output = np.dot(self.weights, self.input) + self.bias
        return self.output
    
    def backward(self, chained_grad, learning_rate):
        weights_grad = np.dot(chained_grad, self.input.T)
        input_grads = np.dot(self.weights.T, chained_grad) 

        self.weights -= learning_rate * weights_grad / chained_grad.shape[1]
        self.bias -= learning_rate * chained_grad.sum(axis=1, keepdims=True) / chained_grad.shape[1]

        return input_grads

# %% [markdown]
# ### 1.1.3 Activation Layer

# %%
# Implementing Activation part as a seperate layer is more intuitive and simplifies the coding  
class activation_layer(Layer):
    def __init__(self, activation, activation_prime):
        self.activation = activation
        self.activation_prime = activation_prime
    
    def forward(self, Xs):
        self.input = Xs
        self.output = self.activation(self.input)
        return self.output

    def backward(self, chained_grad, learning_rate):
        input_grad = self.activation_prime(self.input) * chained_grad
        return input_grad

# %% [markdown]
# ## 1.2 Different Activation Functions

# %% [markdown]
# After implementing the framework of activation layer as the activation_layer class, we need to define certain activation functions, both for forward and backward.
# Here we implemented the four most famous activation functions:
# - Sigmoid
# - Tanh
# - ReLU
# - Leaky ReLU

# %%
# implement 'Sigmoid' activation function for both forward and backward path
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_prime(x):
    sig = (1 / (1 + np.exp(-x)))
    return sig * (1 - sig)


# implement 'Tanh' activation function for both forward and backward path
def tanh(x):
    return np.tanh(x)

def tanh_prime(x):
    return 1 - tanh(x)**2


# implement 'ReLU' activation function for both forward and backward path
def relu(x):
    return np.maximum(0, x)

def relu_prime(x):
    grads = np.zeros_like(x)
    grads[x > 0] = 1 
    return grads


# implement 'Leaky ReLU' activation function for both forward and backward path
def leaky_relu(x):
    return np.maximum(0.1*x, x)

def leaky_relu_prime(x):
    grads = np.full(x.shape, 0.1)
    grads[x > 0.1 * x] = 1
    return grads

# %% [markdown]
# ## 1.3 Different Loss Functions

# %% [markdown]
# One of the elementary parts of each learning procedure is the **Loss function / Cost function**, there are many different
# cost functions for different purposes, here we are implementing three different loss functions.
# - Mean Squared Error (MSE)
# - Cross Entropy
# - Multiclass Hinge loss
#
# As the loss function is the final computation applied on the network's input, the backpropagation strarts on it, so we need
# to implement both the forward path, and the backward path for each loss function.

# %%
# different loss functions

# Mean Squared Error 
def mse(y_true, y_pred):
    return np.mean( (y_true - y_pred)**2 )

def mse_prime(y_true, y_pred):
    grads = 2 * (y_pred - y_true) / np.size(y_true)
    return np.array(grads)



# Cross Entropy vectorized implementation for both forward and backward pass
def cross_entropy(y_true, x):
    loss_of_samples = -np.log(np.exp(x[y_true, range(x.shape[1])]) / np.exp(x).sum(axis=0))
    return loss_of_samples.sum()

def cross_entropy_prime(y_true, x):
    exponents = np.exp(x)
    denoms = exponents.sum(axis=0)                                             
    grads =  exponents / denoms
    grads[y_true, range(x.shape[1])] -= 1    
    return grads



# Multiclass hinge vectorized implementation for both forward and backward pass
def multi_class_hinge(y_true, x, delta=1):
    losses = np.maximum(0, x - x[y_true, range(x.shape[1])] + delta)
    losses[y_true, range(losses.shape[1])] = 0

    return losses.sum() / y_true.size 

def multi_class_hinge_prime(y_true, x, delta=1):
    grads = ((x - x[y_true, range(x.shape[1])]) > 0)
    grads = grads.astype(int)
    grads[y_true, range(grads.shape[1])] = 0                    
    grads[y_true, range(grads.shape[1])] = -grads.sum(axis=0)                 # count the all miss-classified classes 

    return grads / y_true.size

# %% [markdown]
# ## 1.4 L2 Regularization

# %% [markdown]
# In order to prevent our model to overfit, we implement the **L2 regularization** to penalize large values for weights, which is the main cause of overfit. Ofcourse each computation in forward pass will encounter in backward pass, in other words, we need to implement the backward pass as well as forward pass for our regularization term.

# %%
# define a function to add regularization to the loss function

def apply_L2_regularization(weights_list, loss, reg):
    squared_sum_of_weights = 0
    for i in weights_list:
        squared_sum_of_weights += np.sum(i * i)
    return loss + reg * squared_sum_of_weights

def apply_L2_regularization_prime(weights_list, grad, reg):
    grad_of_sum_of_weights = 0
    for i in weights_list:
        grad_of_sum_of_weights += np.sum(i)
    return grad + 2 * reg * grad_of_sum_of_weights

# %% [markdown]
# ## 1.5 Prediction and Accuracy function

# %% [markdown]
# ### 1.5.1 Predict function  (from-scratch version neural network)
#
# Define a function to convert raw output scores of the network/model to class labels.

# %%
def predict(X, network):
    output = X.T
    for layer in network:
        output = layer.forward(output)
    return output.argmax(axis=0)

# %% [markdown]
# ### 1.5.2 accuracy function (PyTorch models)

# %% [markdown]
# Calculates accuracy between truth labels and predictions.

# %%
def accuracy_fn(y_true, y_pred):
    correct = torch.eq(y_true, y_pred).sum().item()
    acc = (correct / len(y_pred)) * 100
    return acc

# %% [markdown]
# ## 1.6 Train functions

# %% [markdown]
# ### 1.6.1 Training function that uses gradient descent to train independent model

# %% [markdown]
# In order to train our independent version neural networks, we're going to  functionize the learning process using `train` function.

# %%
def train(X_train, Y_train, X_test, Y_test, network, loss_function, loss_function_prime, learning_rate, reg_func, reg_func_prime, reg_rate, epochs=100, sgd=False, batch_size=256, verbose=25, **kwargs):
    """Performs the whole training and evaluating procedure for a model on a certain dataset."""
    losses = []
    for epoch in range(epochs):
        weights = []

        # if sgd==True, use stochastic gradient descent optimization method, otherwise use gradient descent/full gradient descent.
        if sgd:
            indices = np.random.choice(np.arange(0, len(X_train)), batch_size, replace=False)
            X_train_batch = X_train[indices]
            y_train_batch = Y_train[indices]
        else:
            X_train_batch = X_train
            y_train_batch = Y_train
        

        output = X_train_batch.T
        
        # foward pass
        for layer in network:
            output = layer.forward(output)
            try:
                weights.append(layer.weights)
            except:
                pass

        # calculate the loss
        loss_without_reg = loss_function(y_train_batch, output)
        losses.append(reg_func(weights, loss_without_reg, reg_rate))

        # start the backpropagation pass
        grad = loss_function_prime(y_train_batch, output)
        grad = reg_func_prime(weights, grad, reg_rate)

        for layer in reversed(network):
            grad = layer.backward(grad, learning_rate)

        if verbose and (epoch % verbose == 0):

            train_predicts = predict(X_train_batch, network)
            test_predicts = predict(X_test, network)

            accuracy_on_train = np.mean(train_predicts == y_train_batch)
            accuracy_on_test = np.mean(test_predicts == Y_test)

            sum_of_weights = 0
            for i in weights:
                sum_of_weights += np.sum(i)

            print(f'epoch {epoch:4}/{epochs} | accuracy on train: {accuracy_on_train:.3f} | accuracy on test: {accuracy_on_test:.3f} | loss: {losses[-1]:.3f} | sum of weights: {sum_of_weights:.4f}')
    print(f'epoch {epoch:4}/{epochs} | accuracy on train: {accuracy_on_train:.3f} | accuracy on test: {accuracy_on_test:.3f} | loss: {losses[-1]:.3f} | sum of weights: {sum_of_weights:.4f}')

# %% [markdown]
# ### 1.6.2 Perform one training epoch on model (PyTorch)

# %%
def train_step(model: torch.nn.Module, 
               data_loader: torch.utils.data.DataLoader, 
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer,
               accuracy_fn,
               device: torch.device = device):
    """Performs a training step/epoch with model trying to learn on data_loader."""

    train_loss, train_acc = 0, 0


    # put model into training mode 
    model.train()


    # add a loop to loop through the training batches
    for batch, (X, y) in enumerate(data_loader):

        # put data on target device
        X, y = X.to(device), y.to(device)

        # 1. forward pass (outputs the raw logits from the model)
        y_pred = model(X)

        # 2. calcualate loss and accuracy (per batch)
        loss = loss_fn(y_pred, y)
        train_loss += loss    # accumlate train loss 
        acc = accuracy_fn(y_true=y, y_pred=y_pred.argmax(dim=1)) # go from logits -> prediction labels
        train_acc += acc
        
        # 3. optimizer zero grad
        optimizer.zero_grad()

        # 4. loss backward
        loss.backward()

        # 5. optimizer step
        optimizer.step()
        
        if batch % 25 == 0:
            print(f"batch (128 samples): {batch:4}/{len(data_loader)} | Train loss: {loss:.5f} | Train accuracy: {acc:.2f}%")    
        
    # divide total train loss and accuracy by length of train dataloader 
    train_loss /= len(data_loader)
    train_acc /= len(data_loader)

    print(f"End of an epoch --> Train loss: {train_loss:.5f} | Train accuracy: {train_acc:.2f}%\n")

# %% [markdown]
# ### 1.6.3 Perform one testing step on whole test dataset (PyTorch)

# %%
def test_step(model: torch.nn.Module,
              data_loader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module,
              accuracy_fn,
              device: torch.device = device):
    """Perfoms a testing loop step on model going over data_loader."""
    test_loss, test_acc = 0, 0

    
    # put the model in eval mode
    model.eval()
    
    # turn on indference mode context manager
    with torch.inference_mode():
        for batch, (X, y) in enumerate(data_loader):
            # send data to the target device
            X, y = X.to(device), y.to(device)
            
            # 1. forward pass (outputs raw logits)
            test_pred = model(X)
            
            # 2. calculate the loss and accuracy
            loss = loss_fn(test_pred, y)
            test_loss += loss
            acc = accuracy_fn(y_true=y, 
                                    y_pred=test_pred.argmax(dim=1)) # logits -> prediction labels
            test_acc += acc
                     
        # # divide total train loss and accuracy by length of test dataloader 
        test_loss /= len(data_loader)
        test_acc /= len(data_loader)
        
        print(f"-------\nTest loss: {test_loss:.5f} | Test accuracy: {test_acc:.2f}%\n-------\n")

# %% [markdown]
# ---
# ---
#
#
# # 2. Implementations
#
#
# ---
# ---

# %% [markdown]
# ## 2.1 Artificial Data classification

# %% [markdown]
# ### 2.1.1 Creating data used for train and test

# %% [markdown]
# using the scikit-learn to create an artifical dataset with two features and 250 samples in three classes.

# %%
N_classes = 3

data = make_classification(n_samples=250, n_features=2, n_classes=N_classes, n_redundant=0, n_informative=2, 
                           hypercube=True, n_clusters_per_class=1, class_sep=1.6, random_state=5)

Xs = data[0]
ys = data[1]

for i in range(N_classes):
    class_i = Xs[ys == i]
    plt.scatter(class_i[:, 0], class_i[:, 1], label=f'class {i}')

plt.title('Dataset with circled test datapoints\n')
plt.legend()
plt.xlabel('feature 1')
plt.ylabel('feature 2')
# Out:
# Text(0, 0.5, 'feature 2')

# %% [markdown]
# ### 2.1.2 Independent neural network for artificial dataset

# %% [markdown]
# #### 2.1.2.1 Defining the network architecture

# %% [markdown]
# Define a network with two hidden layers and Tanh activation function.

# %%
network = [
    Dense_Layer(2, 10),
    activation_layer(tanh, tanh_prime),
    Dense_Layer(10, 10),
    activation_layer(tanh, tanh_prime),
    Dense_Layer(10, 3),
]

# %% [markdown]
# #### 2.1.2.2 Train the defiend network

# %% [markdown]
# Train the defined model on created dataset and evaluate the accuracy on both train and test sets.

# %%
X_train, X_test, y_train, y_test = train_test_split(Xs, ys, test_size=0.2, random_state=3)

train(X_train, 
      y_train, 
      X_test, 
      y_test, 
      network, 
      cross_entropy, 
      cross_entropy_prime, 
      learning_rate=3, 
      reg_func=apply_L2_regularization, 
      reg_func_prime=apply_L2_regularization_prime,
      reg_rate=0, 
      epochs=400,
      verbose=25)
# Out:
# epoch    0/400 | accuracy on train: 0.350 | accuracy on test: 0.280 | loss: 219.653 | sum of weights: 0.1654
# epoch   25/400 | accuracy on train: 0.920 | accuracy on test: 0.940 | loss: 95.630 | sum of weights: -2.6612
# epoch   50/400 | accuracy on train: 0.970 | accuracy on test: 1.000 | loss: 34.248 | sum of weights: -1.6901
# epoch   75/400 | accuracy on train: 0.980 | accuracy on test: 1.000 | loss: 22.817 | sum of weights: -2.4850
# epoch  100/400 | accuracy on train: 0.990 | accuracy on test: 1.000 | loss: 14.371 | sum of weights: -3.9577
# epoch  125/400 | accuracy on train: 0.990 | accuracy on test: 1.000 | loss: 12.114 | sum of weights: -4.4335
# epoch  150/400 | accuracy on train: 0.990 | accuracy on test: 1.000 | loss: 11.417 | sum of weights: -4.6470
# epoch  175/400 | accuracy on train: 0.990 | accuracy on test: 1.000 | loss: 11.120 | sum of weights: -4.8131
# epoch  200/400 | accuracy on train: 0.990 | accuracy on test: 1.000 | loss: 10.946 | sum of weights: -4.9600
# epoch  225/400 | accuracy on train: 0.990 | accuracy on test: 1.000 | loss: 10.827 | sum of weights: -5.0967
# epoch  250/400 | accuracy on train: 0.990 | accuracy on test: 1.000 | loss: 10.735 | sum of weights: -5.2303
# epoch  275/400 | accuracy on train: 0.990 | accuracy on test: 1.000 | loss: 10.652 | sum of weights: -5.3698
# epoch  300/400 | accuracy on train: 0.990 | accuracy on test: 1.000 | loss: 10.536 | sum of weights: -5.5370
# epoch  325/400 | accuracy on train: 0.990 | accuracy on test: 1.000 | loss: 10.092 | sum of weights: -5.8401
# epoch  350/400 | accuracy on train: 0.990 | accuracy on test: 1.000 | loss: 9.753 | sum of weights: -6.2006
# epoch  375/400 | accuracy on train: 0.990 | accuracy on test: 1.000 | loss: 9.630 | sum of weights: -6.4656
# epoch  399/400 | accuracy on train: 0.990 | accuracy on test: 1.000 | loss: 9.559 | sum of weights: -6.4656

# %% [markdown]
# #### 2.1.2.3 Plot decision boundaries for trained model

# %%
output = X_train.T
for layer in network:
    output = layer.forward(output)

    
train_predicts = predict(X_train, network)

# %%
decision_surface(network, predict, plt, Xs, ys, 3)

# %% [markdown]
# ### 2.1.3 PyTorch for artificial dataset

# %% [markdown]
# #### 2.1.3.1 Defining the network architecture

# %% [markdown]
# Define a network with same architecture as above network, but using PyTorch

# %%
class ArtificialData(nn.Module):
    def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
        super().__init__()
        self.layer_stack = nn.Sequential(
            nn.Linear(in_features=input_shape, out_features=hidden_units),
            nn.Tanh(),
            nn.Linear(in_features=hidden_units, out_features=hidden_units),
            nn.Tanh(),
            nn.Linear(in_features=hidden_units, out_features=output_shape)
        )

        
    def forward(self, x):
        return self.layer_stack(x)

# %% [markdown]
# Using the same architecture and optimization technique as above experiment.

# %%
clf_model = ArtificialData(2, 10, 3)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(params=clf_model.parameters(), lr=3)

clf_model
# Out:
# ArtificialData(
#   (layer_stack): Sequential(
#     (0): Linear(in_features=2, out_features=10, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=10, out_features=10, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=10, out_features=3, bias=True)
#   )
# )

# %% [markdown]
# #### 2.1.3.2 Train and evaluatethe defined model

# %%
epochs = 400

train_loss, train_acc = [], []
test_loss, test_acc = [], []

X_train_t, X_test_t, y_train_t, y_test_t = torch.tensor(X_train).type(torch.float), torch.tensor(X_test).type(torch.float), torch.tensor(y_train).type(torch.LongTensor), torch.tensor(y_test).type(torch.LongTensor) 

# add a loop to loop through the training batches
for epoch in range(epochs):
    # put model into training mode 
    clf_model.train()

    # 1. forward pass (outputs the raw logits from the model)
    train_scores = clf_model(X_train_t)
    train_preds = train_scores.detach().numpy().argmax(axis=1) # go from logits -> prediction labels
    
    # 2. calcualate loss and accuracy (per batch)
    loss = loss_fn(train_scores, y_train_t)
    train_loss.append(loss)    # accumlate train loss 
    acc = np.mean(y_train == train_preds)
    train_acc.append(acc)

    # 3. optimizer zero grad
    optimizer.zero_grad()

    # 4. loss backward
    loss.backward()

    # 5. optimizer step
    optimizer.step()

    if epoch % 50 == 0:
        
        print(f"{epoch:4}/{epochs} | Train loss: {loss:.4f} | Train accuracy: {acc:.2f}%")  
          
        # put the model in eval mode
        clf_model.eval()

        # turn on indference mode context manager
        with torch.inference_mode():
            # 1. forward pass (outputs raw logits)
            test_scores = clf_model(X_test_t)
            test_preds = test_scores.numpy().argmax(axis=1) # go from logits -> prediction labels
            

            # 2. calculate the loss and accuracy
            loss = loss_fn(test_scores, y_test_t)
            test_loss.append(loss)

            acc = np.mean(y_test == test_preds)
            test_acc.append(acc)

            print(f"{epoch:4}/{epochs} | Test loss: {loss:.4f}  | Test accuracy: {acc:.2f}%\n")
# Out:
#    0/400 | Train loss: 1.1690 | Train accuracy: 0.09%
#    0/400 | Test loss: 0.8991  | Test accuracy: 0.62%
#
#   50/400 | Train loss: 0.0515 | Train accuracy: 0.99%
#   50/400 | Test loss: 0.0214  | Test accuracy: 1.00%
#
#  100/400 | Train loss: 0.0413 | Train accuracy: 0.99%
#  100/400 | Test loss: 0.0170  | Test accuracy: 1.00%
#
#  150/400 | Train loss: 0.0384 | Train accuracy: 0.99%
#  150/400 | Test loss: 0.0150  | Test accuracy: 1.00%
#
#  200/400 | Train loss: 0.0364 | Train accuracy: 0.99%
#  200/400 | Test loss: 0.0106  | Test accuracy: 1.00%
#
#  250/400 | Train loss: 0.0326 | Train accuracy: 0.99%
#  250/400 | Test loss: 0.0101  | Test accuracy: 1.00%
#
#  300/400 | Train loss: 0.0295 | Train accuracy: 0.99%
#  300/400 | Test loss: 0.0115  | Test accuracy: 1.00%
#
#  350/400 | Train loss: 0.0275 | Train accuracy: 0.99%
#  350/400 | Test loss: 0.0109  | Test accuracy: 1.00%

# %% [markdown]
# #### 2.1.3.3 Plot decision boundaries for trained model

# %%
decision_surface_torch(clf_model, plt, Xs, ys, 3)

# %% [markdown]
# ---

# %% [markdown]
# ## 2.2 Models on MNIST

# %% [markdown]
# ### 2.2.1 Loading MNIST dataset using PyTorch

# %% [markdown]
# In this experiment we use PyTorch to load MNIST dataset for both independent and PyTorch classifiers.

# %%
# setup training and testing data
DATA_PATH = 'D:\PyTorch_datasets'

mnist_train_data = datasets.MNIST(
    root=DATA_PATH,
    train=True,
    download=True,
    transform=ToTensor(),    # how do we want to transform the data
    target_transform=None    # how do we want to transform the labels/targets
)

mnist_test_data = datasets.MNIST(
    root=DATA_PATH,
    train=False,
    download=True,
    transform=ToTensor(),
    target_transform=None
)

# %%
mnist_train_data.data.shape, mnist_train_data.targets.shape
# Out:
# (torch.Size([60000, 28, 28]), torch.Size([60000]))

# %% [markdown]
# ### 2.2.2 Independent neural network on MNIST dataset

# %% [markdown]
# #### 2.2.2.1 make the data ready for Independent model

# %% [markdown]
# The data now we have is in tensor form, we want the data in the form of numpy arrays for our independent model, so the next
# cell is dedicated to transform the data type, as well as its shape, to flatten the 28 * 28 MNIST images.

# %%
# transform data type and shape for training data
X_train_mn = mnist_train_data.data.numpy().reshape(mnist_train_data.data.shape[0], mnist_train_data.data.shape[1] * mnist_train_data.data.shape[2])
y_train_mn = mnist_train_data.targets.numpy()

# transform data type and shape for testing data
X_test_mn = mnist_test_data.data.numpy().reshape(mnist_test_data.data.shape[0], mnist_test_data.data.shape[1] * mnist_test_data.data.shape[2])
y_test_mn = mnist_test_data.targets.numpy()

X_train_mn.shape, y_train_mn.shape, X_test_mn.shape, y_test_mn.shape
# Out:
# ((60000, 784), (60000,), (10000, 784), (10000,))

# %% [markdown]
# #### 2.2.2.2 Define the architecture for network

# %% [markdown]
# Define a network architecture with three hidden layers and **Leaky ReLU** activation function.

# %%
mnist_network = [
    Dense_Layer(784, 100),
    activation_layer(leaky_relu, leaky_relu_prime),
    Dense_Layer(100, 100),
    activation_layer(leaky_relu, leaky_relu_prime),
    Dense_Layer(100, 100),
    activation_layer(leaky_relu, leaky_relu_prime),
    Dense_Layer(100, 10)   
]

# %% [markdown]
# #### 2.2.2.3 Train the defined network

# %% [markdown]
# Train and evaluate the defined independent model on the MNIST dataset. In this experiment we are using stochastic gradient descent (also known as batch gradient descent), with a batch-size of 1024.

# %%
train(X_train_mn, 
      y_train_mn, 
      X_test_mn, 
      y_test_mn, 
      mnist_network, 
      multi_class_hinge, 
      multi_class_hinge_prime, 
      learning_rate=2, 
      reg_func=apply_L2_regularization, 
      reg_func_prime=apply_L2_regularization_prime, 
      reg_rate=0.0, 
      epochs=2000,
      sgd=True,
      batch_size=1024,
      verbose=100)
# Out:
# epoch    0/2000 | accuracy on train: 0.845 | accuracy on test: 0.834 | loss: 8.484 | sum of weights: -8.9254
# epoch  100/2000 | accuracy on train: 0.846 | accuracy on test: 0.837 | loss: 8.509 | sum of weights: -9.2042
# epoch  200/2000 | accuracy on train: 0.817 | accuracy on test: 0.842 | loss: 8.550 | sum of weights: -9.4245
# epoch  300/2000 | accuracy on train: 0.851 | accuracy on test: 0.843 | loss: 8.559 | sum of weights: -9.6560
# epoch  400/2000 | accuracy on train: 0.849 | accuracy on test: 0.847 | loss: 8.577 | sum of weights: -9.8555
# epoch  500/2000 | accuracy on train: 0.857 | accuracy on test: 0.851 | loss: 8.594 | sum of weights: -10.0348
# epoch  600/2000 | accuracy on train: 0.849 | accuracy on test: 0.851 | loss: 8.616 | sum of weights: -10.2073
# epoch  700/2000 | accuracy on train: 0.858 | accuracy on test: 0.856 | loss: 8.629 | sum of weights: -10.3313
# epoch  800/2000 | accuracy on train: 0.864 | accuracy on test: 0.857 | loss: 8.639 | sum of weights: -10.4446
# epoch  900/2000 | accuracy on train: 0.871 | accuracy on test: 0.855 | loss: 8.650 | sum of weights: -10.5827
# epoch 1000/2000 | accuracy on train: 0.856 | accuracy on test: 0.860 | loss: 8.661 | sum of weights: -10.6747
# epoch 1100/2000 | accuracy on train: 0.897 | accuracy on test: 0.862 | loss: 8.661 | sum of weights: -10.7801
# epoch 1200/2000 | accuracy on train: 0.868 | accuracy on test: 0.863 | loss: 8.680 | sum of weights: -10.8710
# epoch 1300/2000 | accuracy on train: 0.867 | accuracy on test: 0.867 | loss: 8.693 | sum of weights: -10.9718
# epoch 1400/2000 | accuracy on train: 0.881 | accuracy on test: 0.867 | loss: 8.703 | sum of weights: -11.0566
# epoch 1500/2000 | accuracy on train: 0.860 | accuracy on test: 0.865 | loss: 8.704 | sum of weights: -11.1478
# epoch 1600/2000 | accuracy on train: 0.878 | accuracy on test: 0.868 | loss: 8.716 | sum of weights: -11.2294
# epoch 1700/2000 | accuracy on train: 0.870 | accuracy on test: 0.867 | loss: 8.721 | sum of weights: -11.3068
# epoch 1800/2000 | accuracy on train: 0.871 | accuracy on test: 0.869 | loss: 8.726 | sum of weights: -11.3662
# epoch 1900/2000 | accuracy on train: 0.890 | accuracy on test: 0.867 | loss: 8.737 | sum of weights: -11.4375
# epoch 1999/2000 | accuracy on train: 0.890 | accuracy on test: 0.867 | loss: 8.737 | sum of weights: -11.4375

# %% [markdown]
# After training the model, predict the label for 16 random samples from test set and plot the output.

# %%
torch.manual_seed(42)

number_of_images = 16
ncols = 4
nrows = 4

# pick some random images from the train set
random_idx = torch.randint(low=0, high=len(mnist_test_data), size=(number_of_images,))#.item()
images = mnist_test_data.data[random_idx].type(torch.float32).numpy().reshape(16, -1)
labels = mnist_test_data.targets[random_idx].numpy()

scores = images.T
for layer in mnist_network:
    scores = layer.forward(scores)
    

preds = predict(images, mnist_network)


# plot the images and the predicted label for each one alongside it's real label
plt.figure(figsize=(9, 9))
for i, img in enumerate(images):
    plt.subplot(nrows, ncols, i+1)
    plt.imshow(img.reshape(28, 28), cmap='gray')#.permute(2, 1, 0))
    
    if labels[i] == preds[i]:
        plt.title(f'true: {mnist_test_data.classes[labels[i]]}, predicted: {mnist_test_data.classes[preds[i]]}', fontsize=9, c='g')
    else:
        plt.title(f'true: {mnist_test_data.classes[labels[i]]}, predicted: {mnist_test_data.classes[preds[i]]}', fontsize=9, c='r')
    plt.grid('off')
    plt.axis('off')

plt.tight_layout()

# %% [markdown]
# ### 2.2.3 PyTorch on MNIST implementation

# %% [markdown]
# #### 2.2.3.1 Make the data ready for PyTorch model

# %% [markdown]
# To perform stochastic gradient descent as optimization technique in PyTorch model, we need to turn our train and test datasets into dataloaders.

# %%
# Turn train and test datasets into DataLoader's
from torch.utils.data import DataLoader

# The chosen batch size for this experiment is 1024 samples
BATCH_SIZE = 1024
mnist_train_dataloader = DataLoader(dataset=mnist_train_data, batch_size=BATCH_SIZE, num_workers=1, shuffle=True)
mnist_test_dataloader = DataLoader(dataset=mnist_test_data, batch_size=BATCH_SIZE, num_workers=1, shuffle=False)

mnist_train_dataloader, mnist_test_dataloader
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x240a86a39d0>,
#  <torch.utils.data.dataloader.DataLoader at 0x240a86a3910>)

# %% [markdown]
# #### 2.2.3.2 Define and the network architecture

# %% [markdown]
# Define a network with same architecture as above network, but using PyTorch. We're using a flatten layer as first layer, which provides us ability to input data with it's original shape, needless to reshape it.

# %%
class MNISTClassifier(nn.Module):
    def __init__(self, input_shape, hidden_units, output_shape):
        super().__init__()
        self.layer_stack = nn.Sequential(
            nn.Flatten(),
            nn.Linear(in_features=input_shape, out_features=hidden_units),
            nn.LeakyReLU(),
            nn.Linear(in_features=hidden_units, out_features=hidden_units),
            nn.LeakyReLU(),
            nn.Linear(in_features=hidden_units, out_features=output_shape)
        )
        
    def forward(self, x):
        return self.layer_stack(x)

# %% [markdown]
# Using the same loss function and optimization technique as above experiment.

# %%
mnist_model = MNISTClassifier(input_shape=784, hidden_units=100, output_shape=10)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(params=mnist_model.parameters(), lr=0.1)

mnist_model
# Out:
# MNISTClassifier(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=784, out_features=100, bias=True)
#     (2): LeakyReLU(negative_slope=0.01)
#     (3): Linear(in_features=100, out_features=100, bias=True)
#     (4): LeakyReLU(negative_slope=0.01)
#     (5): Linear(in_features=100, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# #### 2.2.3.3 Train and evaluate the defined network
#
# Train and evaluate the created model usnig PyTroch on train and test sets.

# %%
torch.manual_seed(42)

# set epochs
epochs = 10

# create an optimization and evaluation loop using train_step() and test_step()
for epoch in tqdm(range(epochs)):
    print(f"Epoch: {epoch}\n-------")
    train_step(model=mnist_model, 
               data_loader=mnist_train_dataloader, 
               loss_fn=loss_fn, 
               optimizer=optimizer, 
               accuracy_fn=accuracy_fn,
               device='cpu')
    
    test_step(model=mnist_model,
              data_loader=mnist_test_dataloader,
              loss_fn=loss_fn,
              accuracy_fn=accuracy_fn,
              device='cpu')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 0
# -------
# batch (128 samples):    0/59 | Train loss: 2.30614 | Train accuracy: 9.38%
# batch (128 samples):   25/59 | Train loss: 2.19803 | Train accuracy: 53.42%
# batch (128 samples):   50/59 | Train loss: 1.79402 | Train accuracy: 62.01%
# End of an epoch --> Train loss: 2.08073 | Train accuracy: 45.26%
#
# -------
# Test loss: 1.49226 | Test accuracy: 68.05%
# -------
#
# Epoch: 1
# -------
# batch (128 samples):    0/59 | Train loss: 1.53625 | Train accuracy: 65.82%
# batch (128 samples):   25/59 | Train loss: 0.89052 | Train accuracy: 77.25%
# batch (128 samples):   50/59 | Train loss: 0.66820 | Train accuracy: 81.64%
# End of an epoch --> Train loss: 0.92545 | Train accuracy: 77.10%
#
# -------
# Test loss: 0.60398 | Test accuracy: 83.37%
# -------
#
# Epoch: 2
# -------
# batch (128 samples):    0/59 | Train loss: 0.63997 | Train accuracy: 81.45%
# batch (128 samples):   25/59 | Train loss: 0.56454 | Train accuracy: 85.74%
# batch (128 samples):   50/59 | Train loss: 0.46883 | Train accuracy: 88.38%
# End of an epoch --> Train loss: 0.52910 | Train accuracy: 85.44%
#
# -------
# Test loss: 0.45132 | Test accuracy: 86.93%
# -------
#
# Epoch: 3
# -------
# batch (128 samples):    0/59 | Train loss: 0.46447 | Train accuracy: 87.40%
# batch (128 samples):   25/59 | Train loss: 0.41735 | Train accuracy: 88.57%
# batch (128 samples):   50/59 | Train loss: 0.38528 | Train accuracy: 89.75%
# End of an epoch --> Train loss: 0.43013 | Train accuracy: 88.01%
#
# -------
# Test loss: 0.38410 | Test accuracy: 89.07%
# -------
#
# Epoch: 4
# -------
# batch (128 samples):    0/59 | Train loss: 0.41563 | Train accuracy: 87.70%
# batch (128 samples):   25/59 | Train loss: 0.36536 | Train accuracy: 88.48%
# batch (128 samples):   50/59 | Train loss: 0.32960 | Train accuracy: 90.82%
# End of an epoch --> Train loss: 0.38297 | Train accuracy: 89.20%
#
# -------
# Test loss: 0.34963 | Test accuracy: 89.81%
# -------
#
# Epoch: 5
# -------
# batch (128 samples):    0/59 | Train loss: 0.34960 | Train accuracy: 90.82%
# batch (128 samples):   25/59 | Train loss: 0.37429 | Train accuracy: 89.06%
# batch (128 samples):   50/59 | Train loss: 0.30469 | Train accuracy: 92.09%
# End of an epoch --> Train loss: 0.35285 | Train accuracy: 90.03%
#
# -------
# Test loss: 0.32763 | Test accuracy: 90.48%
# -------
#
# Epoch: 6
# -------
# batch (128 samples):    0/59 | Train loss: 0.36685 | Train accuracy: 89.65%
# batch (128 samples):   25/59 | Train loss: 0.30521 | Train accuracy: 90.72%
# batch (128 samples):   50/59 | Train loss: 0.35022 | Train accuracy: 90.43%
# End of an epoch --> Train loss: 0.33195 | Train accuracy: 90.52%
#
# -------
# Test loss: 0.31030 | Test accuracy: 90.98%
# -------
#
# Epoch: 7
# -------
# batch (128 samples):    0/59 | Train loss: 0.28828 | Train accuracy: 92.09%
# batch (128 samples):   25/59 | Train loss: 0.28514 | Train accuracy: 91.11%
# batch (128 samples):   50/59 | Train loss: 0.29101 | Train accuracy: 90.72%
# End of an epoch --> Train loss: 0.31556 | Train accuracy: 90.99%
#
# -------
# Test loss: 0.29780 | Test accuracy: 91.37%
# -------
#
# Epoch: 8
# -------
# batch (128 samples):    0/59 | Train loss: 0.34134 | Train accuracy: 90.14%
# batch (128 samples):   25/59 | Train loss: 0.25494 | Train accuracy: 92.19%
# batch (128 samples):   50/59 | Train loss: 0.30170 | Train accuracy: 92.09%
# End of an epoch --> Train loss: 0.30199 | Train accuracy: 91.40%
#
# -------
# Test loss: 0.28375 | Test accuracy: 91.91%
# -------
#
# Epoch: 9
# -------
# batch (128 samples):    0/59 | Train loss: 0.30671 | Train accuracy: 91.02%
# batch (128 samples):   25/59 | Train loss: 0.29001 | Train accuracy: 91.60%
# batch (128 samples):   50/59 | Train loss: 0.29303 | Train accuracy: 91.11%
# End of an epoch --> Train loss: 0.28930 | Train accuracy: 91.75%
#
# -------
# Test loss: 0.27432 | Test accuracy: 92.09%
# -------

# %% [markdown]
# After training the model, predict the label for 16 random samples from test set and plot the output.
#
# *Note: The purpose of this experiment is not comparing the results of the independent and PyTorch-based models (as the learning procedure is a little bit different, in other words, the circumstance for two models is not exactly the same).*

# %%
torch.manual_seed(42)

number_of_images = 16
ncols = 4
nrows = 4

# pick some random images from the train set
random_idx = torch.randint(low=0, high=len(mnist_test_data), size=(number_of_images,))#.item()
images = mnist_test_data.data[random_idx].type(torch.float32)
labels = mnist_test_data.targets[random_idx]

mnist_model.eval()
with torch.inference_mode():
    scores = mnist_model(images)

preds = torch.softmax(scores, dim=1).argmax(dim=1)


# plot the images and the predicted label for each one alongside it's real label
plt.figure(figsize=(9, 9))
for i, img in enumerate(images):
    plt.subplot(nrows, ncols, i+1)
    plt.imshow(img.type(torch.int), cmap='gray')#.permute(2, 1, 0))
    
    if labels[i] == preds[i]:
        plt.title(f'true: {mnist_test_data.classes[labels[i]]}, predicted: {mnist_test_data.classes[preds[i]]}', fontsize=9, c='g')
    else:
        plt.title(f'true: {mnist_test_data.classes[labels[i]]}, predicted: {mnist_test_data.classes[preds[i]]}', fontsize=9, c='r')
    plt.grid('off')
    plt.axis('off')

plt.tight_layout()

# %% [markdown]
# ## 2.4 Models on CIFAR-10

# %% [markdown]
# ### 2.4.1 Loading CIFAR-10 dataset using PyTorch

# %% [markdown]
# In this experiment we use PyTorch to load CIFAR-10 dataset for both independent and PyTorch classifiers.

# %% [markdown]
# ### 2.4.2 Independent neural network on CIFAR-10 dataset

# %% [markdown]
# #### 2.4.2.1 Load the data for the independent model using PyTorch

# %%
# setup training data

DATA_PATH = 'D:\PyTorch_datasets'

device = 'cuda' if torch.cuda.is_available() else 'cpu'

cifar10_train_data = datasets.CIFAR10(
    root=DATA_PATH,
    train=True,
    download=True,
    transform=ToTensor(),    # how do we want to transform the data
    target_transform=None    # how do we want to transform the labels/targets
)

cifar10_test_data = datasets.CIFAR10(
    root=DATA_PATH,
    train=False,
    download=True,
    transform=ToTensor(),
    target_transform=None
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# transform data type and shape for training data
cifar10_X_train = cifar10_train_data.data.reshape(cifar10_train_data.data.shape[0], -1).astype(np.float32)
cifar10_y_train = np.array(cifar10_train_data.targets)

# transform data type and shape for testing data
cifar10_X_test = cifar10_test_data.data.reshape(cifar10_test_data.data.shape[0], -1).astype(np.float32)
cifar10_y_test = np.array(cifar10_test_data.targets)

cifar10_X_train.shape, cifar10_y_train.shape, cifar10_X_test.shape, cifar10_y_test.shape
# Out:
# ((50000, 3072), (50000,), (10000, 3072), (10000,))

# %%
class_names = cifar10_train_data.classes
print(class_names)
# Out:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# Subtract the mean of all training images from both train and test sets, in order to make the mean of train images equal to zero.

# %%
mean_of_images = np.mean(cifar10_X_train, axis=0)

cifar10_X_train -= mean_of_images
cifar10_X_test -= mean_of_images

# %% [markdown]
# #### 2.4.2.2 Define the architecture of network

# %% [markdown]
# Define a network architecture with three hidden layers and **Leaky ReLU** activation function.

# %%
c10_network = [
    Dense_Layer(3072, 4000),
    activation_layer(leaky_relu, leaky_relu_prime),
    Dense_Layer(4000, 1000),
    activation_layer(leaky_relu, leaky_relu_prime),
    Dense_Layer(1000, 4000),
    activation_layer(leaky_relu, leaky_relu_prime),
    Dense_Layer(4000, 10),
]

# %% [markdown]
# #### 2.4.2.3 Train and evaluate the defined network

# %% [markdown]
# Train and evaluate the defined independent model on the CIFAR-10 dataset. In this experiment we are using stochastic gradient descent (also known as batch gradient descent), with a batch-size of 256.

# %%
train(  cifar10_X_train, 
        cifar10_y_train, 
        cifar10_X_test, 
        cifar10_y_test,  
        c10_network, 
        multi_class_hinge, 
        multi_class_hinge_prime, 
        learning_rate=1e-1, 
        reg_func=apply_L2_regularization, 
        reg_func_prime=apply_L2_regularization_prime, 
        reg_rate=1e-9, 
        epochs=960,
        sgd=True,
        batch_size=256,
        verbose=30)
# Out:
# epoch    0/960 | accuracy on train: 0.402 | accuracy on test: 0.348 | loss: 4.850 | sum of weights: -393.2439
# epoch   30/960 | accuracy on train: 0.477 | accuracy on test: 0.341 | loss: 4.568 | sum of weights: -418.1389
# epoch   60/960 | accuracy on train: 0.480 | accuracy on test: 0.346 | loss: 4.763 | sum of weights: -441.5904
# epoch   90/960 | accuracy on train: 0.441 | accuracy on test: 0.342 | loss: 4.570 | sum of weights: -461.6985
# epoch  120/960 | accuracy on train: 0.414 | accuracy on test: 0.357 | loss: 4.620 | sum of weights: -479.8441
# epoch  150/960 | accuracy on train: 0.496 | accuracy on test: 0.345 | loss: 4.299 | sum of weights: -494.1549
# epoch  180/960 | accuracy on train: 0.461 | accuracy on test: 0.354 | loss: 4.786 | sum of weights: -508.0264
# epoch  210/960 | accuracy on train: 0.469 | accuracy on test: 0.368 | loss: 4.405 | sum of weights: -520.6207
# epoch  240/960 | accuracy on train: 0.461 | accuracy on test: 0.361 | loss: 4.211 | sum of weights: -530.4402
# epoch  270/960 | accuracy on train: 0.480 | accuracy on test: 0.366 | loss: 4.145 | sum of weights: -539.7492
# epoch  300/960 | accuracy on train: 0.535 | accuracy on test: 0.359 | loss: 4.342 | sum of weights: -547.2021
# epoch  330/960 | accuracy on train: 0.504 | accuracy on test: 0.363 | loss: 4.421 | sum of weights: -554.4246
# epoch  360/960 | accuracy on train: 0.461 | accuracy on test: 0.367 | loss: 4.152 | sum of weights: -561.4558
# epoch  390/960 | accuracy on train: 0.496 | accuracy on test: 0.360 | loss: 4.508 | sum of weights: -568.7505
# epoch  420/960 | accuracy on train: 0.508 | accuracy on test: 0.367 | loss: 4.522 | sum of weights: -574.7813
# epoch  450/960 | accuracy on train: 0.516 | accuracy on test: 0.358 | loss: 4.298 | sum of weights: -580.4098
# epoch  480/960 | accuracy on train: 0.520 | accuracy on test: 0.374 | loss: 4.506 | sum of weights: -586.1028
# epoch  510/960 | accuracy on train: 0.523 | accuracy on test: 0.368 | loss: 4.393 | sum of weights: -590.1090
# epoch  540/960 | accuracy on train: 0.539 | accuracy on test: 0.368 | loss: 4.509 | sum of weights: -594.4909
# epoch  570/960 | accuracy on train: 0.496 | accuracy on test: 0.360 | loss: 4.515 | sum of weights: -597.6801
# epoch  600/960 | accuracy on train: 0.543 | accuracy on test: 0.371 | loss: 4.354 | sum of weights: -601.1883
# epoch  630/960 | accuracy on train: 0.566 | accuracy on test: 0.371 | loss: 4.404 | sum of weights: -604.4180
# epoch  660/960 | accuracy on train: 0.574 | accuracy on test: 0.376 | loss: 4.568 | sum of weights: -608.1555
# epoch  690/960 | accuracy on train: 0.508 | accuracy on test: 0.363 | loss: 4.562 | sum of weights: -610.7638
# epoch  720/960 | accuracy on train: 0.570 | accuracy on test: 0.365 | loss: 4.417 | sum of weights: -614.0921
# epoch  750/960 | accuracy on train: 0.566 | accuracy on test: 0.369 | loss: 4.306 | sum of weights: -616.8151
# epoch  780/960 | accuracy on train: 0.590 | accuracy on test: 0.369 | loss: 4.395 | sum of weights: -618.3620
# epoch  810/960 | accuracy on train: 0.547 | accuracy on test: 0.364 | loss: 4.577 | sum of weights: -621.1204
# epoch  840/960 | accuracy on train: 0.602 | accuracy on test: 0.380 | loss: 4.331 | sum of weights: -623.2012
# epoch  870/960 | accuracy on train: 0.609 | accuracy on test: 0.374 | loss: 4.324 | sum of weights: -625.7479
# epoch  900/960 | accuracy on train: 0.605 | accuracy on test: 0.370 | loss: 4.584 | sum of weights: -627.2707
# epoch  930/960 | accuracy on train: 0.605 | accuracy on test: 0.371 | loss: 4.331 | sum of weights: -628.9651
# epoch  959/960 | accuracy on train: 0.605 | accuracy on test: 0.371 | loss: 4.295 | sum of weights: -628.9651

# %% [markdown]
# After training the model, predict the label for 16 random samples from test set and plot the output.

# %%
np.random.seed(12)

number_of_images = 16
ncols = 4
nrows = 4


# pick some random images from the train set
random_indices = np.random.choice(np.arange(0, len(cifar10_test_data.data)), number_of_images, replace=False)
random_images = cifar10_test_data.data[random_indices]
random_labels = np.array(cifar10_test_data.targets)[random_indices]

random_images = random_images.reshape(random_images.shape[0], -1).astype(np.float32)
random_images -= mean_of_images

# do the forward pass and output the computed scores for each class
output = random_images.T
for layer in c10_network:
    output = layer.forward(output)

    
# convert the scores to class labels    
predicts = predict(random_images, c10_network)
accuracy_on_train = np.mean(predicts == random_labels)


# add the mean of images back
random_images += mean_of_images


# plot the images and the predicted label for each one alongside it's real label
plt.figure(figsize=(9, 9))
for i in range(number_of_images):
    plt.subplot(nrows, ncols, i+1)
    plt.imshow(random_images[i, :].reshape(32, 32, 3).astype('int'))
    
    if random_labels[i] == predicts[i]:
        plt.title(f'true: {class_names[random_labels[i]]}, predicted: {class_names[predicts[i]]}', fontsize=9, c='g')
    else:
        plt.title(f'true: {class_names[random_labels[i]]}, predicted: {class_names[predicts[i]]}', fontsize=9, c='r')
    plt.grid('off')
    plt.axis('off')

plt.tight_layout()

# %% [markdown]
# ### 2.4.3 PyTorch on Cifar-10 dataset

# %% [markdown]
# #### 2.4.3.1 Make the data ready for PyTorch model

# %% [markdown]
# To perform stochastic gradient descent as optimization technique in PyTorch model, we need to turn our train and test datasets into dataloaders.

# %%
# setup the batch size hyperparameter
BATCH_SIZE = 256

# turn dataset into iterables (batches)
cifar10_train_dataloader = DataLoader(dataset=cifar10_train_data, batch_size=BATCH_SIZE, shuffle=True)

cifar10_test_dataloader = DataLoader(dataset=cifar10_test_data, batch_size=1000, shuffle=False)

cifar10_train_dataloader, cifar10_test_dataloader
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x240e11382e0>,
#  <torch.utils.data.dataloader.DataLoader at 0x240e1138a30>)

# %%
# check out what's inside the training dataloader
train_features_batch, train_label_batch = next(iter(cifar10_train_dataloader))

train_features_batch.shape, train_label_batch.shape
# Out:
# (torch.Size([256, 3, 32, 32]), torch.Size([256]))

# %% [markdown]
# #### 2.4.3.2 Define the architecture of network

# %% [markdown]
# Replicate the architecture of above netwrok using PyTorch.

# %%
class Cifar10ModelV0(nn.Module):
    def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
        super().__init__()
        self.layer_stack = nn.Sequential(
            nn.Flatten(),
            nn.Linear(in_features=input_shape, out_features=4000),
            nn.LeakyReLU(),
            nn.Linear(in_features=4000, out_features=1000),
            nn.LeakyReLU(),
            nn.Linear(in_features=1000, out_features=4000),
            nn.LeakyReLU(),
            nn.Linear(in_features=4000, out_features=output_shape)
        )

        
    def forward(self, x):
        return self.layer_stack(x)

# %% [markdown]
# Using the same loss function and optimization technique as above experiment.

# %%
torch.manual_seed(42)

cifar10_model = Cifar10ModelV0(input_shape=3072, hidden_units=0, output_shape=len(class_names)).to('cpu')

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(params=cifar10_model.parameters(), lr=0.01)

cifar10_model
# Out:
# Cifar10ModelV0(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=3072, out_features=4000, bias=True)
#     (2): LeakyReLU(negative_slope=0.01)
#     (3): Linear(in_features=4000, out_features=1000, bias=True)
#     (4): LeakyReLU(negative_slope=0.01)
#     (5): Linear(in_features=1000, out_features=4000, bias=True)
#     (6): LeakyReLU(negative_slope=0.01)
#     (7): Linear(in_features=4000, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# #### 2.4.3.3 Train the defined model

# %% [markdown]
# Train and evaluate the created PyTorch model on train and test sets.

# %%
torch.manual_seed(42)

# set epochs
epochs = 10

# create an optimization and evaluation loop using train_step() and test_step()
for epoch in tqdm(range(epochs)):
    print(f"Epoch: {epoch}\n-------")
    train_step(model=cifar10_model, 
               data_loader=cifar10_train_dataloader, 
               loss_fn=loss_fn, 
               optimizer=optimizer, 
               accuracy_fn=accuracy_fn,
               device='cpu')
    
    test_step(model=cifar10_model,
              data_loader=cifar10_test_dataloader,
              loss_fn=loss_fn,
              accuracy_fn=accuracy_fn,
              device='cpu')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 0
# -------
# batch (128 samples):    0/196 | Train loss: 1.94991 | Train accuracy: 26.17%
# batch (128 samples):   25/196 | Train loss: 1.94852 | Train accuracy: 27.73%
# batch (128 samples):   50/196 | Train loss: 1.96115 | Train accuracy: 29.30%
# batch (128 samples):   75/196 | Train loss: 1.90731 | Train accuracy: 26.95%
# batch (128 samples):  100/196 | Train loss: 1.92821 | Train accuracy: 32.03%
# batch (128 samples):  125/196 | Train loss: 1.91665 | Train accuracy: 31.64%
# batch (128 samples):  150/196 | Train loss: 1.93705 | Train accuracy: 32.03%
# batch (128 samples):  175/196 | Train loss: 1.94158 | Train accuracy: 30.08%
# End of an epoch --> Train loss: 1.94213 | Train accuracy: 30.34%
#
# -------
# Test loss: 1.92559 | Test accuracy: 31.05%
# -------
#
# Epoch: 1
# -------
# batch (128 samples):    0/196 | Train loss: 1.93584 | Train accuracy: 30.86%
# batch (128 samples):   25/196 | Train loss: 1.91112 | Train accuracy: 31.64%
# batch (128 samples):   50/196 | Train loss: 2.00170 | Train accuracy: 30.08%
# batch (128 samples):   75/196 | Train loss: 1.90336 | Train accuracy: 30.86%
# batch (128 samples):  100/196 | Train loss: 1.95200 | Train accuracy: 32.03%
# batch (128 samples):  125/196 | Train loss: 1.83817 | Train accuracy: 37.89%
# batch (128 samples):  150/196 | Train loss: 1.89211 | Train accuracy: 36.33%
# batch (128 samples):  175/196 | Train loss: 1.89928 | Train accuracy: 32.03%
# End of an epoch --> Train loss: 1.90206 | Train accuracy: 31.98%
#
# -------
# Test loss: 1.89082 | Test accuracy: 32.17%
# -------
#
# Epoch: 2
# -------
# batch (128 samples):    0/196 | Train loss: 1.89731 | Train accuracy: 31.64%
# batch (128 samples):   25/196 | Train loss: 1.88737 | Train accuracy: 32.42%
# batch (128 samples):   50/196 | Train loss: 1.92286 | Train accuracy: 28.91%
# batch (128 samples):   75/196 | Train loss: 1.87162 | Train accuracy: 32.03%
# batch (128 samples):  100/196 | Train loss: 1.86016 | Train accuracy: 36.33%
# batch (128 samples):  125/196 | Train loss: 1.86553 | Train accuracy: 32.03%
# batch (128 samples):  150/196 | Train loss: 1.89870 | Train accuracy: 32.03%
# batch (128 samples):  175/196 | Train loss: 1.85230 | Train accuracy: 32.03%
# End of an epoch --> Train loss: 1.86940 | Train accuracy: 33.38%
#
# -------
# Test loss: 1.86388 | Test accuracy: 33.79%
# -------
#
# Epoch: 3
# -------
# batch (128 samples):    0/196 | Train loss: 1.83852 | Train accuracy: 35.94%
# batch (128 samples):   25/196 | Train loss: 1.76205 | Train accuracy: 37.11%
# batch (128 samples):   50/196 | Train loss: 1.86954 | Train accuracy: 33.20%
# batch (128 samples):   75/196 | Train loss: 1.85606 | Train accuracy: 36.72%
# batch (128 samples):  100/196 | Train loss: 1.85024 | Train accuracy: 31.64%
# batch (128 samples):  125/196 | Train loss: 1.85472 | Train accuracy: 33.59%
# batch (128 samples):  150/196 | Train loss: 1.91121 | Train accuracy: 31.25%
# batch (128 samples):  175/196 | Train loss: 1.90718 | Train accuracy: 33.59%
# End of an epoch --> Train loss: 1.84315 | Train accuracy: 34.52%
#
# -------
# Test loss: 1.86290 | Test accuracy: 33.44%
# -------
#
# Epoch: 4
# -------
# batch (128 samples):    0/196 | Train loss: 1.93891 | Train accuracy: 28.91%
# batch (128 samples):   25/196 | Train loss: 1.90026 | Train accuracy: 25.00%
# batch (128 samples):   50/196 | Train loss: 1.77695 | Train accuracy: 39.45%
# batch (128 samples):   75/196 | Train loss: 1.85412 | Train accuracy: 35.55%
# batch (128 samples):  100/196 | Train loss: 1.80422 | Train accuracy: 35.94%
# batch (128 samples):  125/196 | Train loss: 1.72960 | Train accuracy: 36.33%
# batch (128 samples):  150/196 | Train loss: 1.75787 | Train accuracy: 37.89%
# batch (128 samples):  175/196 | Train loss: 1.75783 | Train accuracy: 39.06%
# End of an epoch --> Train loss: 1.81617 | Train accuracy: 35.41%
#
# -------
# Test loss: 1.84111 | Test accuracy: 34.64%
# -------
#
# Epoch: 5
# -------
# batch (128 samples):    0/196 | Train loss: 1.77735 | Train accuracy: 40.62%
# batch (128 samples):   25/196 | Train loss: 1.78909 | Train accuracy: 33.98%
# batch (128 samples):   50/196 | Train loss: 1.83752 | Train accuracy: 32.42%
# batch (128 samples):   75/196 | Train loss: 1.87195 | Train accuracy: 33.20%
# batch (128 samples):  100/196 | Train loss: 1.79585 | Train accuracy: 37.50%
# batch (128 samples):  125/196 | Train loss: 1.74236 | Train accuracy: 36.33%
# batch (128 samples):  150/196 | Train loss: 1.80901 | Train accuracy: 30.86%
# batch (128 samples):  175/196 | Train loss: 1.71985 | Train accuracy: 38.28%
# End of an epoch --> Train loss: 1.79160 | Train accuracy: 36.29%
#
# -------
# Test loss: 1.77192 | Test accuracy: 36.63%
# -------
#
# Epoch: 6
# -------
# batch (128 samples):    0/196 | Train loss: 1.78958 | Train accuracy: 35.94%
# batch (128 samples):   25/196 | Train loss: 1.77620 | Train accuracy: 32.42%
# batch (128 samples):   50/196 | Train loss: 1.76934 | Train accuracy: 37.11%
# batch (128 samples):   75/196 | Train loss: 1.86114 | Train accuracy: 34.77%
# batch (128 samples):  100/196 | Train loss: 1.81118 | Train accuracy: 37.11%
# batch (128 samples):  125/196 | Train loss: 1.76116 | Train accuracy: 37.11%
# batch (128 samples):  150/196 | Train loss: 1.72349 | Train accuracy: 39.84%
# batch (128 samples):  175/196 | Train loss: 1.87625 | Train accuracy: 32.42%
# End of an epoch --> Train loss: 1.76841 | Train accuracy: 37.03%
#
# -------
# Test loss: 1.76056 | Test accuracy: 36.77%
# -------
#
# Epoch: 7
# -------
# batch (128 samples):    0/196 | Train loss: 1.72479 | Train accuracy: 40.23%
# batch (128 samples):   25/196 | Train loss: 1.70804 | Train accuracy: 41.41%
# batch (128 samples):   50/196 | Train loss: 1.72293 | Train accuracy: 38.28%
# batch (128 samples):   75/196 | Train loss: 1.75124 | Train accuracy: 37.89%
# batch (128 samples):  100/196 | Train loss: 1.72569 | Train accuracy: 37.11%
# batch (128 samples):  125/196 | Train loss: 1.70016 | Train accuracy: 40.23%
# batch (128 samples):  150/196 | Train loss: 1.75815 | Train accuracy: 35.94%
# batch (128 samples):  175/196 | Train loss: 1.75322 | Train accuracy: 39.06%
# End of an epoch --> Train loss: 1.74868 | Train accuracy: 37.66%
#
# -------
# Test loss: 1.72893 | Test accuracy: 38.22%
# -------
#
# Epoch: 8
# -------
# batch (128 samples):    0/196 | Train loss: 1.73112 | Train accuracy: 34.77%
# batch (128 samples):   25/196 | Train loss: 1.74561 | Train accuracy: 41.41%
# batch (128 samples):   50/196 | Train loss: 1.70438 | Train accuracy: 39.45%
# batch (128 samples):   75/196 | Train loss: 1.71569 | Train accuracy: 34.77%
# batch (128 samples):  100/196 | Train loss: 1.83475 | Train accuracy: 36.33%
# batch (128 samples):  125/196 | Train loss: 1.71472 | Train accuracy: 40.23%
# batch (128 samples):  150/196 | Train loss: 1.68625 | Train accuracy: 37.50%
# batch (128 samples):  175/196 | Train loss: 1.72578 | Train accuracy: 36.72%
# End of an epoch --> Train loss: 1.72996 | Train accuracy: 38.43%
#
# -------
# Test loss: 1.71684 | Test accuracy: 39.04%
# -------
#
# Epoch: 9
# -------
# batch (128 samples):    0/196 | Train loss: 1.69377 | Train accuracy: 38.67%
# batch (128 samples):   25/196 | Train loss: 1.69081 | Train accuracy: 38.67%
# batch (128 samples):   50/196 | Train loss: 1.75022 | Train accuracy: 33.59%
# batch (128 samples):   75/196 | Train loss: 1.85025 | Train accuracy: 34.77%
# batch (128 samples):  100/196 | Train loss: 1.74362 | Train accuracy: 41.41%
# batch (128 samples):  125/196 | Train loss: 1.66438 | Train accuracy: 39.06%
# batch (128 samples):  150/196 | Train loss: 1.66702 | Train accuracy: 41.41%
# batch (128 samples):  175/196 | Train loss: 1.72703 | Train accuracy: 40.23%
# End of an epoch --> Train loss: 1.70978 | Train accuracy: 39.08%
#
# -------
# Test loss: 1.69514 | Test accuracy: 39.59%
# -------

# %%
test_step(model=cifar10_model,
              data_loader=cifar10_test_dataloader,
              loss_fn=loss_fn,
              accuracy_fn=accuracy_fn,
              device='cpu')
# Out:
# -------
# Test loss: 1.69514 | Test accuracy: 39.59%
# -------

# %% [markdown]
# After training the model, predict the label for 16 random samples (same as above experiment) from test set and plot the output.
#
# *Note: The purpose of this experiment is not comparing the results of the independent and PyTorch-based models (as the learning procedure is a little bit different, in other words, the circumstance for two models isn't exactly the same).*

# %%
np.random.seed(12)

number_of_images = 16
ncols = 4
nrows = 4

# pick some random images from the train set
random_idx = torch.tensor(np.random.choice(np.arange(0, len(cifar10_test_data.data)), number_of_images, replace=False))
images = torch.tensor(cifar10_test_data.data[random_idx]).type(torch.float32).permute(0, 3, 1, 2)
labels = torch.tensor(cifar10_test_data.targets)[random_idx]

cifar10_model.eval()
with torch.inference_mode():
    scores = cifar10_model(images)
preds = torch.softmax(scores, dim=1).argmax(dim=1)


# plot the images and the predicted label for each one alongside it's real label
plt.figure(figsize=(9, 9))
for i, img in enumerate(images):
    plt.subplot(nrows, ncols, i+1)
#     print(img.type())
    plt.imshow(img.type(torch.int).permute(2, 1, 0))
    
    if labels[i] == preds[i]:
        plt.title(f'true: {classes[labels[i]]}, predicted: {classes[preds[i]]}', fontsize=9, c='g')
    else:
        plt.title(f'true: {classes[labels[i]]}, predicted: {classes[preds[i]]}', fontsize=9, c='r')
    plt.grid('off')
    plt.axis('off')

plt.tight_layout()
